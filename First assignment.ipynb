# %% [markdown]
# <h1>Welcome to my assignment</h1>
# <h3>Please if you find a mistake or a way to improve my work,send me feedback </h3>

# %% [markdown]
# <b>First : </b>Importing the liberies and install what I need

# %%
import pandas as pd
import numpy as np
# !pip install folium
import folium
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
import matplotlib.cm  as cm
import matplotlib.colors as colors
print('ok')
# Out:
# ...
# ok

# %% [markdown]
# <b>Now we import the data from Wikipidia using pandas.read_html I thought that this is easier than Beautifulsoup</b>

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
df
# Out:
# [    Postal Code           Borough  \
#  0           M1A      Not assigned
#  1           M2A      Not assigned
#  2           M3A        North York
#  3           M4A        North York
#  4           M5A  Downtown Toronto
#  ..          ...               ...
#  175         M5Z      Not assigned
#  176         M6Z      Not assigned
#  177         M7Z      Not assigned
#  178         M8Z         Etobicoke
#  179         M9Z      Not assigned
#
#                                           Neighbourhood
#  0                                         Not assigned
#  1                                         Not assigned
#  2                                            Parkwoods
#  3                                     Victoria Village
#  4                            Regent Park, Harbourfront
#  ..                                                 ...
#  175                                       Not assigned
#  176                                       Not assigned
# ...

# %% [markdown]
# <b>After that I relised that there is a lot of tables and I used to use the first table which contain our data</b>

# %%
df=df[0]

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %%
print('There are {} Borough and {} Neighberhood'.format(len (df.Borough.unique()),df.shape[0]))
# Out:
# There are 11 Borough and 180 Neighberhood

# %% [markdown]
# <b>Oh cheese! there is no latiture or longiture we have to make once using geopy and Nominatin </b>

# %% [markdown]
# <b>First I created two new column on the dataframe and gave them zero value</b>

# %%
df['LAT']=0
df['LNG']=0
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood  LAT  LNG
# 0                                         Not assigned    0    0
# 1                                         Not assigned    0    0
# 2                                            Parkwoods    0    0
# 3                                     Victoria Village    0    0
# 4                            Regent Park, Harbourfront    0    0
# ..                                                 ...  ...  ...
# 175                                       Not assigned    0    0
# ...

# %% [markdown]
# <b> I made shortcut for Neighbourhood and Borough</b>

# %%
NH=df['Neighbourhood']
BR=df['Borough']

# %% [markdown]
# <b>Here I created a loop if the borough has the "Not assigned" it will delete the row and if not it will give me the values of latiture
# and longiture and insert it in LAT and LNG on the dataframe</b>

# %%
for i in range(180) :
    if BR[i]=='Not assigned':
        df.drop(i,axis=0,inplace=True)
    else :
        adress='{} , Toronto, ON, Canada'.format(BR[i])
        geolocator = Nominatim(user_agent="ca_explorer")
        location=geolocator.geocode(adress)
        latitude=location.latitude
        longitude=location.longitude
        df['LAT'][i]="{}".format(latitude)
        df['LNG'][i]="{}".format(longitude)
df
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# <b>Now I had to make new index</b>

# %%
df.set_index('Postal Code',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood          LAT  \
# 0                                            Parkwoods   43.7543263
# 1                                     Victoria Village   43.7543263
# 2                            Regent Park, Harbourfront   43.6563221
# 3                     Lawrence Manor, Lawrence Heights   43.7543263
# 4          Queen's Park, Ontario Provincial Government   43.6563221
# ..                                                 ...          ...
# 98       The Kingsway, Montgomery Road, Old Mill North   43.6435559
# ...

# %% [markdown]
# <b>This is now Toronto location</b>

# %%
adress=' Toronto, ON, Canada'
geolocator = Nominatim(user_agent="ca_explorer")
location=geolocator.geocode(adress)
latitude=location.latitude
longitude=location.longitude
print(adress)
print('latitude :  ',latitude)
print('longitude :  ',longitude)
# Out:
#  Toronto, ON, Canada
# latitude :   43.6534817
# longitude :   -79.3839347

# %% [markdown]
# <b>now created a map</b>

# %%
Tomap=folium.Map(location=[latitude,longitude],zoom_start=10)
for lat, lng, borough, neighborhood in zip(df['LAT'],df['LNG'],df['Borough'],df['Neighbourhood']):
    label='{},{}'.format(neighborhood,borough)
    label=folium.Popup(label, perse_html=True)
    folium.CircleMarker(
    [lat,lng],
    redius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=1,
    prese_html=False).add_to(Tomap)
Tomap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <b>Now the K-Means and Clustering</b>

# %%
df.drop('Borough',axis=1,inplace=True)

# %%
df.drop('Postal Code',axis=1,inplace=True)

# %%
df.set_index('Neighbourhood')
print('ok')
# Out:
# ok

# %%
df
# Out:
#                                          Neighbourhood          LAT  \
# 0                                            Parkwoods   43.7543263
# 1                                     Victoria Village   43.7543263
# 2                            Regent Park, Harbourfront   43.6563221
# 3                     Lawrence Manor, Lawrence Heights   43.7543263
# 4          Queen's Park, Ontario Provincial Government   43.6563221
# ..                                                 ...          ...
# 98       The Kingsway, Montgomery Road, Old Mill North   43.6435559
# 99                                Church and Wellesley   43.6563221
# 100  Business reply mail Processing Centre, South C...  43.72178945
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...   43.6435559
# 102  Mimico NW, The Queensway West, South of Bloor,...   43.6435559
#
#                     LNG
# 0    -79.44911696639593
# 1    -79.44911696639593
# 2           -79.3809161
# 3    -79.44911696639593
# ...

# %%
kclusters = 2
df_clustering = df.drop('Neighbourhood',1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_clustering)
kmeans.labels_[0:10]
# Out:
# array([1, 1, 0, 1, 0, 1, 0, 1, 0, 0], dtype=int32)

# %%
df['Cluster Labels']=kmeans.labels_
df
# Out:
#                                          Neighbourhood          LAT  \
# 0                                            Parkwoods   43.7543263
# 1                                     Victoria Village   43.7543263
# 2                            Regent Park, Harbourfront   43.6563221
# 3                     Lawrence Manor, Lawrence Heights   43.7543263
# 4          Queen's Park, Ontario Provincial Government   43.6563221
# ..                                                 ...          ...
# 98       The Kingsway, Montgomery Road, Old Mill North   43.6435559
# 99                                Church and Wellesley   43.6563221
# 100  Business reply mail Processing Centre, South C...  43.72178945
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...   43.6435559
# 102  Mimico NW, The Queensway West, South of Bloor,...   43.6435559
#
#                     LNG  Cluster Labels
# 0    -79.44911696639593               1
# 1    -79.44911696639593               1
# ...

# %% [markdown]
# <b>Now the last map</b>

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []
for lat, lon, poi, cluster in zip(df['LAT'], df['LNG'], df['Neighbourhood'], df['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster],
        fill=True,
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
